# %% [markdown]
# 2^1000的所有位数之和

# %%
def add(ori_num: list, add_num: list):
    while(len(ori_num)!=len(add_num)):
        if len(ori_num)>len(add_num):
            add_num.append(0)
        else:
            ori_num.append(0)
    sum_num = [0] * len(ori_num)
    for i in range(0, len(add_num)):
        if ori_num[i] + add_num[i] <= 9:
            sum_num[i] = sum_num[i] + ori_num[i] + add_num[i]
        else:
            sum_num[i] = ori_num[i] + add_num[i] + sum_num[i] - 10
            if i != len(ori_num) - 1:
                sum_num[i + 1] = sum_num[i + 1] + 1
            else:
                sum_num.append(1)
    return sum_num

x=[2]
for i in range(1,1000):
    x=add(x,x)
sum(x)

print(len(x))
print(sum(x))
# Out:
# 302
# 1366

# %% [markdown]
# ~~对于这个数,python中最大的float64也不够用,因此创建一个新的"数字结构".函数不要对输入参数进行修改,而是创建一个新的.创造全0列表:[1]*1000~~
# 实际上python的int是几乎无限的--只取决于内存.
